# %% [markdown]
# # Stacked LSTM Blood Glucose Pipeline for Colab
#
# This notebook is standalone: it defines the XML parser, feature engineering, windowing, scaling, model, training, testing, metrics, and export steps in one place. It does not import project modules.
#
# Expected OhioT1DM layout can be any of these common Colab or Kaggle shapes:
#
# - `/content/drive/MyDrive/OhioT1DM/2018/train/*.xml`
# - `/content/drive/MyDrive/<folder>/OhioT1DM/2018/train/*.xml`
# - `/kaggle/input/<dataset>/OhioT1DM/2018/train/*.xml`
# - `/kaggle/input/<dataset>/2018/train/*.xml`
# - a manually configured path in `DATA_DIR` below.

# %%
# !unzip -P "...@@@!!==/\/\/\/\~~~~~BGLP-1804-BGLP~~~~~/\/\/\/\==!!@@@..." /content/OhioT1DM.zip -d /content/dataset

BASE_DIR = '/content/dataset/OhioT1DM'
# Out:
# Archive:  /content/OhioT1DM.zip
#    creating: /content/dataset/OhioT1DM/
#    creating: /content/dataset/OhioT1DM/2018/
#    creating: /content/dataset/OhioT1DM/2018/test/
#   inflating: /content/dataset/OhioT1DM/2018/test/559-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2018/test/563-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2018/test/570-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2018/test/575-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2018/test/588-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2018/test/591-ws-testing.xml
#    creating: /content/dataset/OhioT1DM/2018/train/
#   inflating: /content/dataset/OhioT1DM/2018/train/559-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2018/train/563-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2018/train/570-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2018/train/575-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2018/train/588-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2018/train/591-ws-training.xml
#    creating: /content/dataset/OhioT1DM/2020/
#    creating: /content/dataset/OhioT1DM/2020/test/
#   inflating: /content/dataset/OhioT1DM/2020/test/540-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2020/test/544-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2020/test/552-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2020/test/567-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2020/test/584-ws-testing.xml
#   inflating: /content/dataset/OhioT1DM/2020/test/596-ws-testing.xml
#    creating: /content/dataset/OhioT1DM/2020/train/
#   inflating: /content/dataset/OhioT1DM/2020/train/540-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2020/train/544-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2020/train/552-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2020/train/567-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2020/train/584-ws-training.xml
#   inflating: /content/dataset/OhioT1DM/2020/train/596-ws-training.xml

# %%
# Optional install cell. Uncomment only if your Colab image is missing a package.
# !pip install -q tensorflow scikit-learn pandas matplotlib

import os
import random
import sys
import warnings
import xml.etree.ElementTree as ET
from datetime import datetime
from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler

warnings.filterwarnings("ignore")
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.losses import Poisson
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.20.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# -----------------------------
# Configuration
# -----------------------------

DATA_DIR =  "/content/dataset/OhioT1DM"
USE_GOOGLE_DRIVE_ON_COLAB = True
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/stacked_lstm_outputs12345678"

def running_on_colab():
    try:
        import google.colab  # noqa: F401
        return True
    except Exception:
        return False

def setup_output_dir():
    if running_on_colab() and USE_GOOGLE_DRIVE_ON_COLAB:
        from google.colab import drive
        drive.mount("/content/drive")
        output_dir = Path(DRIVE_OUTPUT_DIR)
    else:
        output_dir = Path("stacked_lstm_outputs")
    output_dir.mkdir(parents=True, exist_ok=True)
    return output_dir

OUTPUT_DIR = setup_output_dir()

CFG = {
    "cohorts": {
        "2018": [559, 563, 570, 575, 588, 591],
        "2020": [540, 544, 552, 567, 584, 596],
    },
    "train_suffix": "-ws-training.xml",
    "test_suffix": "-ws-testing.xml",
    "resample_freq": "5min",
    "lookback_minutes": 30,
    "forecast_minutes": 30,
    "freq_minutes": 5,
    "rolling_insulin_window": 36,
    "excluded_features": ["acceleration", "basis_steps", "basis_air_temperature", "basis_heart_rate"],
    "cv": {
        "n_splits": 5,
        "shuffle": True,
        "random_state": 42,
    },
    "model": {
        "units": 128,
        "dropout": 0.2,
        "dense_units": [512, 128],
        "learning_rate": 0.01,
        "epochs": 200,
        "batch_size": 256,
        "validation_split": 0.1,
        "early_stopping_patience": 128,
        "reduce_lr_patience": 32,
        "reduce_lr_factor": 0.5,
        "min_lr": 1e-6,
    },
}

print("Outputs will be saved to:", OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Outputs will be saved to: /content/drive/MyDrive/stacked_lstm_outputs12345678

# %%
# -----------------------------
# XML parsing and feature engineering
# -----------------------------

TS_FORMATS = ("%d-%m-%Y %H:%M:%S", "%Y-%m-%d %H:%M:%S", "%m/%d/%Y %H:%M:%S", "%d-%m-%Y %H:%M")
HIGH_MISSING_FEATURES = {"acceleration", "basis_steps", "basis_air_temperature", "basis_heart_rate"}
LOCF_FEATURES = ("basal", "basis_gsr", "finger_stick")
ZERO_IMPUTE_FEATURES = ("bolus", "meal", "exercise", "basis_skin_temperature", "basis_sleep")
POINT_VALUE_ATTRS = {
    "bolus": "dose",
    "meal": "carbs",
    "finger_stick": "value",
    "basal": "value",
    "basis_gsr": "value",
    "basis_skin_temperature": "value",
}

def parse_ts(ts_str):
    if isinstance(ts_str, datetime):
        return ts_str
    if ts_str is None or pd.isna(ts_str):
        return None
    for fmt in TS_FORMATS:
        try:
            return datetime.strptime(str(ts_str).strip(), fmt)
        except ValueError:
            pass
    return None

def parse_feature_dataframe(xml_path, feature):
    empty = pd.DataFrame(columns=["value"], index=pd.DatetimeIndex([]))
    if not Path(xml_path).exists():
        return empty
    root = ET.parse(xml_path).getroot()
    container = root.find(feature)
    if container is None:
        return empty
    records = []
    for el in container:
        if feature == "bolus":
            ts = el.get("ts_begin") or el.get("ts")
            value = el.get("dose")
        elif feature == "temp_basal":
            ts = el.get("ts_begin") or el.get("ts")
            value = el.get("value")
        elif feature == "exercise":
            ts = el.get("ts")
            value = el.get("duration")
        else:
            ts = el.get("ts")
            value = el.get("value")
        records.append({"ts": ts, "value": value})
    if not records:
        return empty
    df = pd.DataFrame(records).dropna(subset=["ts", "value"])
    df["ts"] = df["ts"].apply(parse_ts)
    df["value"] = pd.to_numeric(df["value"], errors="coerce")
    df = df.dropna().set_index("ts").sort_index()
    return df[~df.index.duplicated(keep="first")]

def align_glucose_to_grid(glucose_df, resample_freq):
    if glucose_df.empty:
        return glucose_df
    grouped = glucose_df.groupby(level=0).mean().sort_index()
    freq_delta = pd.Timedelta(resample_freq)
    elapsed = grouped.index - grouped.index.min()
    has_single_phase = pd.Index(elapsed % freq_delta).nunique() <= 1
    if has_single_phase:
        grid = pd.date_range(grouped.index.min(), grouped.index.max(), freq=resample_freq)
        return grouped.reindex(grid)
    rounded = grouped.copy()
    rounded.index = rounded.index.round(resample_freq)
    rounded = rounded.groupby(level=0).mean().sort_index()
    grid = pd.date_range(rounded.index.min(), rounded.index.max(), freq=resample_freq)
    return rounded.reindex(grid)

def parse_events(xml_path, feature):
    columns = ["ts", "ts_begin", "ts_end", "value"]
    root = ET.parse(xml_path).getroot()
    container = root.find(feature)
    if container is None:
        return pd.DataFrame(columns=columns)
    records = []
    for el in container:
        ts = el.get("ts")
        ts_begin = el.get("ts_begin") or el.get("tbegin")
        ts_end = el.get("ts_end") or el.get("tend")
        if feature == "basis_sleep":
            value = 1
        elif feature == "exercise":
            ts_begin = ts_begin or ts
            duration = pd.to_numeric(el.get("duration"), errors="coerce")
            begin = parse_ts(ts_begin) if ts_begin else None
            if begin is not None and not pd.isna(duration):
                ts_end = begin + pd.Timedelta(minutes=float(duration))
            value = el.get("intensity") or 1
        elif feature == "temp_basal":
            value = el.get("value") or el.get("dose") or el.get("rate")
        else:
            value = el.get(POINT_VALUE_ATTRS.get(feature, "value"))
        records.append({"ts": ts, "ts_begin": ts_begin, "ts_end": ts_end, "value": value})
    df = pd.DataFrame(records, columns=columns)
    if df.empty:
        return df
    for col in ["ts", "ts_begin", "ts_end"]:
        df[col] = df[col].apply(parse_ts)
    df["value"] = pd.to_numeric(df["value"], errors="coerce")
    return df.dropna(subset=["value"])

def empty_aligned(glucose_index, column_name):
    return pd.DataFrame({column_name: np.nan}, index=glucose_index)

def align_to_glucose_index(df, glucose_index, column_name, agg="mean"):
    if df.empty:
        return empty_aligned(glucose_index, column_name)
    aligned = df.copy()
    nearest_pos = glucose_index.get_indexer(aligned.index, method="nearest")
    aligned = aligned[nearest_pos >= 0]
    nearest_pos = nearest_pos[nearest_pos >= 0]
    if aligned.empty:
        return empty_aligned(glucose_index, column_name)
    aligned.index = glucose_index.take(nearest_pos)
    aligned = aligned.rename(columns={"value": column_name})
    if agg == "sum":
        aligned = aligned.groupby(level=0).sum()
    elif agg == "count":
        aligned = aligned.groupby(level=0).count()
    else:
        aligned = aligned.groupby(level=0).mean()
    return aligned.reindex(glucose_index)

def align_point_feature(xml_path, feature, glucose_index, column_name=None, agg="mean"):
    column_name = column_name or feature
    events = parse_events(xml_path, feature)
    if events.empty:
        return empty_aligned(glucose_index, column_name)
    ts = events["ts"].where(events["ts"].notna(), events["ts_begin"])
    valid = ts.notna()
    if not valid.any():
        return empty_aligned(glucose_index, column_name)
    df = events.loc[valid, ["value"]].copy()
    df.index = pd.DatetimeIndex(ts.loc[valid])
    return align_to_glucose_index(df, glucose_index, column_name, agg=agg)

def align_interval_feature(xml_path, feature, glucose_index, column_name=None, default_value=1.0):
    column_name = column_name or feature
    events = parse_events(xml_path, feature)
    out = pd.Series(0.0, index=glucose_index, name=column_name)
    counts = pd.Series(0.0, index=glucose_index)
    if events.empty:
        return out.to_frame()
    for _, row in events.iterrows():
        begin, end = row["ts_begin"], row["ts_end"]
        if pd.isna(begin) or pd.isna(end):
            continue
        if end < begin:
            begin, end = end, begin
        value = row["value"] if not pd.isna(row["value"]) else default_value
        mask = (glucose_index >= begin) & (glucose_index <= end)
        out.loc[mask] += float(value)
        counts.loc[mask] += 1
    covered = counts > 0
    out.loc[covered] = out.loc[covered] / counts.loc[covered]
    return out.to_frame()

def apply_temp_basal_override(master):
    if "temp_basal" not in master.columns:
        return master
    master = master.copy()
    master["temp_basal"] = master["temp_basal"].fillna(0)
    temp_override = master["temp_basal"].ne(0)
    master.loc[temp_override, "basal"] = master.loc[temp_override, "temp_basal"]
    if {"bolus", "basal"}.issubset(master.columns):
        master["total_insulin"] = master["bolus"] + master["basal"] * (5 / 60)
    return master.drop(columns=["temp_basal"])

def build_patient_master(xml_path, cfg):
    xml_path = Path(xml_path)
    gl = parse_feature_dataframe(xml_path, "glucose_level")
    if gl.empty:
        return pd.DataFrame()
    gl = align_glucose_to_grid(gl, cfg["resample_freq"])
    gl["glucose_level"] = gl["value"]
    gl = gl.drop(columns="value")
    idx = gl.index

    master = gl.join([
        align_point_feature(xml_path, "bolus", idx, agg="sum"),
        align_point_feature(xml_path, "bolus", idx, "bolus_count", agg="count"),
        align_point_feature(xml_path, "meal", idx, agg="sum"),
        align_point_feature(xml_path, "basal", idx),
        align_interval_feature(xml_path, "temp_basal", idx),
        align_interval_feature(xml_path, "exercise", idx),
        align_point_feature(xml_path, "basis_gsr", idx),
        align_point_feature(xml_path, "finger_stick", idx),
        align_point_feature(xml_path, "basis_skin_temperature", idx),
        align_interval_feature(xml_path, "basis_sleep", idx),
    ], how="left")

    zero_cols = [c for c in ZERO_IMPUTE_FEATURES if c in master.columns]
    locf_cols = [c for c in LOCF_FEATURES if c in master.columns]
    master[zero_cols] = master[zero_cols].fillna(0)
    master[locf_cols] = master[locf_cols].ffill().fillna(0)
    master = apply_temp_basal_override(master)
    master["bolus_count"] = master["bolus_count"].fillna(0)
    master["total_insulin"] = master["bolus"] + master["basal"] * (5 / 60)
    master["insulin_count"] = master["bolus_count"]
    master["insulin_3h_std"] = master["total_insulin"].rolling(cfg["rolling_insulin_window"], min_periods=1).std().fillna(0)
    master["daily_exercise"] = master["exercise"].gt(0).groupby(master.index.date).transform("max").astype(int)
    master = master.drop(columns=["bolus_count"])
    master = master.drop(columns=[c for c in HIGH_MISSING_FEATURES if c in master.columns])
    return master

def find_xml_files(base_dir, cfg):
    base_dir = Path(base_dir)
    train_files, test_files = {}, {}
    for year, patient_ids in cfg["cohorts"].items():
        for pid in patient_ids:
            key = f"{pid}_{year}"
            train_path = base_dir / year / "train" / f"{pid}{cfg['train_suffix']}"
            test_path = base_dir / year / "test" / f"{pid}{cfg['test_suffix']}"
            if train_path.exists():
                train_files[key] = train_path
            else:
                print("Missing train file:", train_path)
            if test_path.exists():
                test_files[key] = test_path
            else:
                print("Missing test file:", test_path)
    return train_files, test_files

def build_all_masters(file_dict, cfg):
    masters = {}
    for key, path in sorted(file_dict.items()):
        df = build_patient_master(path, cfg)
        masters[key] = df
        print(f"{key:10s} rows={len(df):6d} cols={list(df.columns)}")
    return masters

# %%
# -----------------------------
# Windowing, scaling, and metrics
# -----------------------------

TARGET_COL = "glucose_level"
class DatasetScaler:
    def __init__(self):
        self.scaler_glucose = MinMaxScaler()
        self.scaler_y = MinMaxScaler()
        self.fitted = False

    def fit(self, X_train_3d, y_train):
        self.scaler_glucose.fit(X_train_3d[:, :, 0].reshape(-1, 1))
        self.scaler_y.fit(y_train)
        self.fitted = True
        return self

    def transform_3d(self, *arrays):
        if not self.fitted:
            raise RuntimeError("DatasetScaler must be fitted before transform.")
        out = []
        for X in arrays:
            Xs = X.copy()
            n, steps, _ = Xs.shape
            Xs[:, :, 0] = self.scaler_glucose.transform(Xs[:, :, 0].reshape(-1, 1)).reshape(n, steps)
            out.append(Xs.astype(np.float32))
        return out

    def transform_y(self, *arrays):
        if not self.fitted:
            raise RuntimeError("DatasetScaler must be fitted before transform.")
        return [self.scaler_y.transform(y).astype(np.float32) for y in arrays]

    def inverse_transform_y(self, y_scaled):
        if not self.fitted:
            raise RuntimeError("DatasetScaler must be fitted before inverse transform.")
        return self.scaler_y.inverse_transform(y_scaled)



def create_multistep_dataset(df, target_col, lookback_steps, forecast_steps, feature_cols, freq_minutes):
    feature_data = df[feature_cols].values.astype(np.float32)
    target_data = df[target_col].values.astype(np.float32)
    expected_delta = pd.Timedelta(minutes=freq_minutes) if isinstance(df.index, pd.DatetimeIndex) else None
    X, y = [], []
    for i in range(len(df) - lookback_steps - forecast_steps + 1):
        if expected_delta is not None:
            idx = df.index[i : i + lookback_steps + forecast_steps]
            if not idx.to_series().diff().iloc[1:].eq(expected_delta).all():
                continue
        x_window = feature_data[i : i + lookback_steps, :]
        y_window = target_data[i + lookback_steps : i + lookback_steps + forecast_steps]
        if np.isnan(x_window).any() or np.isnan(y_window).any():
            continue
        X.append(x_window)
        y.append(y_window)
    if not X:
        return np.empty((0, lookback_steps, len(feature_cols)), dtype=np.float32), np.empty((0, forecast_steps), dtype=np.float32)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32)

def build_global_dataset(patient_dfs, lookback_steps, forecast_steps, target_col, feature_cols, freq_minutes):
    all_X, all_y = [], []
    min_len = lookback_steps + forecast_steps
    for pid, df in patient_dfs.items():
        if df.empty or len(df) < min_len:
            print(f"Skipping {pid}: only {len(df)} rows")
            continue
        Xp, yp = create_multistep_dataset(df, target_col, lookback_steps, forecast_steps, feature_cols, freq_minutes)
        if len(Xp) == 0:
            print(f"Skipping {pid}: no complete windows")
            continue
        all_X.append(Xp)
        all_y.append(yp)
        print(f"{pid:10s} windows={len(Xp):6d}")
    if not all_X:
        raise ValueError("No valid patient windows were built.")
    return np.concatenate(all_X, axis=0), np.concatenate(all_y, axis=0)

def prepare_raw_datasets(train_masters, test_masters, cfg):
    """Build the single glucose_level-only dataset using raw glucose values."""
    lb_steps = cfg["lookback_minutes"] // cfg["freq_minutes"]
    fc_steps = cfg["forecast_minutes"] // cfg["freq_minutes"]

    feature_cols = [TARGET_COL]
    tag = "glucose_level only (raw)"
    print("\nBuilding dataset:", tag)

    X_train, y_train = build_global_dataset(
        train_masters, lb_steps, fc_steps, TARGET_COL, feature_cols, cfg["freq_minutes"]
    )
    X_test, y_test = build_global_dataset(
        test_masters,  lb_steps, fc_steps, TARGET_COL, feature_cols, cfg["freq_minutes"]
    )

    scaler = DatasetScaler().fit(X_train, y_train)
    (X_train_s,) = scaler.transform_3d(X_train)
    (X_test_s,)  = scaler.transform_3d(X_test)
    (y_train_s,) = scaler.transform_y(y_train)
    (y_test_s,)  = scaler.transform_y(y_test)

    print(f"{tag}: X_train={X_train_s.shape}, X_test={X_test_s.shape}, features={len(feature_cols)}")
    return [{
        "tag": tag,
        "feature_cols": feature_cols,
        "X_train_3d": X_train_s,
        "X_test_3d":  X_test_s,
        "y_train":    y_train,
        "y_test":     y_test,
        "y_train_s":  y_train_s,
        "y_test_s":   y_test_s,
        "scaler":     scaler,
    }]

# %%
# -----------------------------
# Build masters and datasets from XML
# -----------------------------

train_files, test_files = find_xml_files(DATA_DIR, CFG)
print(f"Discovered {len(train_files)} train files and {len(test_files)} test files")

train_masters = build_all_masters(train_files, CFG)
test_masters = build_all_masters(test_files, CFG)

if not train_masters or not test_masters:
    raise RuntimeError("No training/testing data loaded. Check DATA_DIR and dataset layout.")

# Optional cache for inspection or reuse in later Colab/Kaggle cells.
processed_dir = OUTPUT_DIR / "processed"
(processed_dir / "train").mkdir(parents=True, exist_ok=True)
(processed_dir / "test").mkdir(parents=True, exist_ok=True)
for key, df in train_masters.items():
    if not df.empty:
        df.to_csv(processed_dir / "train" / f"{key}_train_master.csv", index_label="ts")
for key, df in test_masters.items():
    if not df.empty:
        df.to_csv(processed_dir / "test" / f"{key}_test_master.csv", index_label="ts")

variants = prepare_raw_datasets(train_masters, test_masters, CFG)
# Out:
# Discovered 12 train files and 12 test files
# 540_2020   rows= 13109 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 544_2020   rows= 12672 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 552_2020   rows= 11098 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 559_2018   rows= 12081 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 563_2018   rows= 13097 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 567_2020   rows= 13536 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 570_2018   rows= 11611 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 575_2018   rows= 13103 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 584_2020   rows= 13247 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 588_2018   rows= 13105 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 591_2018   rows= 12756 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 596_2020   rows= 13630 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 540_2020   rows=  3066 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 544_2020   rows=  3136 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 552_2020   rows=  3950 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 559_2018   rows=  2877 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 563_2018   rows=  2692 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 567_2020   rows=  2870 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 570_2018   rows=  2879 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 575_2018   rows=  2719 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 584_2020   rows=  2995 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 588_2018   rows=  2881 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 591_2018   rows=  2847 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
# 596_2020   rows=  3002 cols=['glucose_level', 'bolus', 'meal', 'basal', 'exercise', 'basis_gsr', 'finger_stick', 'basis_skin_temperature', 'basis_sleep', 'total_insulin', 'insulin_count', 'insulin_3h_std', 'daily_exercise']
#
# Building dataset: glucose_level only (raw)
# 540_2020   windows= 11617
# 544_2020   windows= 10378
# 552_2020   windows=  8597
# 559_2018   windows= 10323
# 563_2018   windows= 11882
# 567_2020   windows= 10224
# 570_2018   windows= 10751
# 575_2018   windows= 11065
# 584_2020   windows= 11497
# 588_2018   windows= 12522
# 591_2018   windows= 10554
# 596_2020   windows= 10596
# 540_2020   windows=  2797
# 544_2020   windows=  2639
# 552_2020   windows=  2243
# 559_2018   windows=  2382
# 563_2018   windows=  2526
# 567_2020   windows=  2257
# 570_2018   windows=  2635
# 575_2018   windows=  2469
# 584_2020   windows=  2489
# 588_2018   windows=  2758
# 591_2018   windows=  2705
# 596_2020   windows=  2666
# glucose_level only (raw): X_train=(130006, 6, 1), X_test=(30566, 6, 1), features=1

# %%
def rmse(y_true, y_pred):
    return float(np.sqrt(mean_squared_error(y_true.ravel(), y_pred.ravel())))

def mae(y_true, y_pred):
    return float(mean_absolute_error(y_true.ravel(), y_pred.ravel()))

def r2(y_true, y_pred):
    return float(r2_score(y_true.ravel(), y_pred.ravel()))

def mard(y_true, y_pred):
    y_true_flat = y_true.ravel()
    y_pred_flat = y_pred.ravel()
    mask = y_true_flat != 0
    return float(np.mean(np.abs(y_true_flat[mask] - y_pred_flat[mask]) / np.abs(y_true_flat[mask])) * 100)

def compute_all_metrics(y_true, y_pred):
    return {"rmse": rmse(y_true, y_pred), "mae": mae(y_true, y_pred), "r2": r2(y_true, y_pred), "mard": mard(y_true, y_pred)}

def all_horizons(y):
    """Return all fc_steps forecast targets (shape: N x fc_steps)."""
    return y.astype(np.float32)

def inverse_all_horizons(target_scaler, y_all_scaled):
    """Inverse-transform all forecast steps (shape: N x fc_steps → mg/dL)."""
    return target_scaler.inverse_transform_y(y_all_scaled)

# %%
# ─────────────────────────────────────────────────────────────────────────────
# Stacked LSTM model and training pipeline (5-fold cross-validation)
#
# For each variant:
#   1. KFold splits the training windows into 5 folds.
#   2. For each fold, a fresh model is trained on the other 4 folds and
#      evaluated on the held-out fold using the same metrics as the final
#      test phase (RMSE, MAE, R², MARD — overall + per forecast step).
#   3. Fold metrics are aggregated (mean ± std) to report CV performance.
#   4. A final model is then trained on the FULL training set and evaluated
#      once on the untouched OhioT1DM test set, exactly as before.
#
# No model weights, checkpoints, or training backups are written to disk;
# everything lives in memory for the duration of this cell.
# ─────────────────────────────────────────────────────────────────────────────

def build_stacked_lstm(input_shape, cfg, fc_steps=1):
    mc = cfg["model"]
    model = Sequential([
        Input(shape=input_shape),
        LSTM(mc["units"], return_sequences=True),
        Dropout(mc["dropout"]),
        LSTM(mc["units"]),
        Dense(mc["dense_units"][0], activation="relu"),
        Dense(mc["dense_units"][1], activation="relu"),
        Dense(fc_steps, activation="exponential"),  # predict all 6 forecast steps
    ])
    model.compile(optimizer=Adam(mc["learning_rate"]), loss=Poisson(name="negative_log_likelihood"))
    return model


def make_callbacks(cfg):
    """EarlyStopping + ReduceLROnPlateau only — no checkpointing or backups."""
    mc = cfg["model"]
    return [
        EarlyStopping(
            monitor="val_loss",
            patience=mc["early_stopping_patience"],
            restore_best_weights=True,
        ),
        ReduceLROnPlateau(
            monitor="val_loss",
            factor=mc["reduce_lr_factor"],
            patience=mc["reduce_lr_patience"],
            min_lr=mc["min_lr"],
        ),
    ]


def fit_stacked_lstm(X_tr, y_tr, X_val, y_val, cfg, fc_steps):
    """Build and train a fresh model, using (X_val, y_val) for validation/early stopping."""
    model = build_stacked_lstm((X_tr.shape[1], X_tr.shape[2]), cfg, fc_steps=fc_steps)
    history = model.fit(
        X_tr,
        y_tr,
        validation_data=(X_val, y_val),
        epochs=cfg["model"]["epochs"],
        batch_size=cfg["model"]["batch_size"],
        callbacks=make_callbacks(cfg),
        verbose=1,
    )
    return model, history


def evaluate_stacked_lstm(model, X_eval, y_eval_s, y_eval_raw, scaler, cfg, fc_steps):
    """Predict and compute the same metrics used in the test phase."""
    preds_s = model.predict(X_eval, verbose=0)                 # N x fc_steps (scaled)
    preds   = inverse_all_horizons(scaler, preds_s)             # N x fc_steps (mg/dL)
    actual  = all_horizons(y_eval_raw)                          # N x fc_steps (mg/dL)

    overall_metrics = compute_all_metrics(actual, preds)

    per_step_metrics = {}
    for step_idx in range(fc_steps):
        step_min = (step_idx + 1) * cfg["freq_minutes"]
        per_step_metrics[f"+{step_min}min"] = compute_all_metrics(
            actual[:, step_idx:step_idx + 1], preds[:, step_idx:step_idx + 1]
        )
    return preds, actual, overall_metrics, per_step_metrics


def cross_validate_stacked_lstm(variant, cfg, fc_steps):
    """5-fold CV over the training windows for a single variant."""
    X_train       = variant["X_train_3d"]
    y_train_s     = all_horizons(variant["y_train_s"])   # scaled targets, all fc_steps
    y_train_raw   = variant["y_train"]                   # raw (mg/dL) targets, all fc_steps
    scaler        = variant["scaler"]

    cv_cfg = cfg["cv"]
    kf = KFold(n_splits=cv_cfg["n_splits"], shuffle=cv_cfg["shuffle"], random_state=cv_cfg["random_state"])

    fold_overall_metrics = []
    fold_per_step_metrics = []

    for fold_idx, (tr_idx, val_idx) in enumerate(kf.split(X_train), start=1):
        print(f"\n--- Fold {fold_idx}/{cv_cfg['n_splits']} ({variant['tag']}) ---")
        X_tr, X_val           = X_train[tr_idx], X_train[val_idx]
        y_tr_s, y_val_s        = y_train_s[tr_idx], y_train_s[val_idx]
        y_val_raw             = y_train_raw[val_idx]

        model, _ = fit_stacked_lstm(X_tr, y_tr_s, X_val, y_val_s, cfg, fc_steps)
        _, _, overall_metrics, per_step_metrics = evaluate_stacked_lstm(
            model, X_val, y_val_s, y_val_raw, scaler, cfg, fc_steps
        )

        print(f"Fold {fold_idx} metrics:", {k: round(v, 4) for k, v in overall_metrics.items()})
        fold_overall_metrics.append(overall_metrics)
        fold_per_step_metrics.append(per_step_metrics)
        tf.keras.backend.clear_session()

    # ── Aggregate fold metrics (mean ± std) ───────────────────────────────────
    cv_overall_df = pd.DataFrame(fold_overall_metrics)
    cv_overall_summary = {
        f"cv_{metric}_mean": cv_overall_df[metric].mean() for metric in cv_overall_df.columns
    }
    cv_overall_summary.update({
        f"cv_{metric}_std": cv_overall_df[metric].std() for metric in cv_overall_df.columns
    })

    horizon_tags = list(fold_per_step_metrics[0].keys())
    cv_per_step_summary = {}
    for horizon_tag in horizon_tags:
        horizon_df = pd.DataFrame([fold[horizon_tag] for fold in fold_per_step_metrics])
        cv_per_step_summary[horizon_tag] = {
            "mean": horizon_df.mean().to_dict(),
            "std":  horizon_df.std().to_dict(),
        }

    return cv_overall_df, cv_overall_summary, cv_per_step_summary


def train_and_test_stacked_lstm(variant, cfg):
    fc_steps = cfg["forecast_minutes"] // cfg["freq_minutes"]

    # ── 5-fold cross-validation on the training set ───────────────────────────
    cv_overall_df, cv_overall_summary, cv_per_step_summary = cross_validate_stacked_lstm(variant, cfg, fc_steps)

    print(f"\n[CV] {variant['tag']} — mean ± std over {cfg['cv']['n_splits']} folds:")
    for metric in ["rmse", "mae", "r2", "mard"]:
        mean_v = cv_overall_summary[f"cv_{metric}_mean"]
        std_v  = cv_overall_summary[f"cv_{metric}_std"]
        print(f"  {metric.upper():5s}: {mean_v:.4f} ± {std_v:.4f}")

    # ── Final model: train on the FULL training set, evaluate on the test set ─
    X_train       = variant["X_train_3d"]
    X_test        = variant["X_test_3d"]
    y_train_all_s = all_horizons(variant["y_train_s"])
    y_test_all_s  = all_horizons(variant["y_test_s"])

    print(f"\n[Final fit] Training {variant['tag']} on full training set...")
    final_model, history = fit_stacked_lstm(
        X_train, y_train_all_s, X_test, y_test_all_s, cfg, fc_steps
    )

    preds, actual, test_metrics, per_step_metrics = evaluate_stacked_lstm(
        final_model, X_test, y_test_all_s, variant["y_test"], variant["scaler"], cfg, fc_steps
    )

    return (
        final_model, history, preds, test_metrics, per_step_metrics,
        cv_overall_df, cv_overall_summary, cv_per_step_summary,
    )


# ── Run ────────────────────────────────────────────────────────────────────────
results = []
cv_results_by_tag = {}
predictions_by_tag = {}

for variant in variants:
    print("\n" + "=" * 80)
    print("Training STACKED_LSTM:", variant["tag"])
    (
        model, history, preds, test_metrics, per_step_metrics,
        cv_overall_df, cv_overall_summary, cv_per_step_summary,
    ) = train_and_test_stacked_lstm(variant, CFG)

    predictions_by_tag[variant["tag"]] = preds
    cv_results_by_tag[variant["tag"]] = {
        "cv_overall_df": cv_overall_df,
        "cv_overall_summary": cv_overall_summary,
        "cv_per_step_summary": cv_per_step_summary,
    }

    record = {
        "model":    "STACKED_LSTM",
        "features": variant["tag"],
        **{f"test_{k}": round(v, 4) for k, v in test_metrics.items()},
        **{k: round(v, 4) for k, v in cv_overall_summary.items()},
    }
    print("\nResult:", record)
    print("Per-step test metrics (all 6 forecast horizons):")
    for horizon_tag, m in per_step_metrics.items():
        print(f"  {horizon_tag}: RMSE={m['rmse']:.4f}  MAE={m['mae']:.4f}  MARD={m['mard']:.4f}%  R²={m['r2']:.4f}")
    results.append(record)
    tf.keras.backend.clear_session()

results_df = pd.DataFrame(results).sort_values("test_rmse").reset_index(drop=True)
results_df
# Out:
# ================================================================================
# Training STACKED_LSTM: glucose_level only (raw)
#
# --- Fold 1/5 (glucose_level only (raw)) ---
# Epoch 1/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.6634 - val_loss: 0.6577 - learning_rate: 0.0100
# Epoch 2/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6559 - val_loss: 0.6575 - learning_rate: 0.0100
# Epoch 3/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6557 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 4/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6556 - val_loss: 0.6575 - learning_rate: 0.0100
# Epoch 5/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6556 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 6/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6556 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 7/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6556 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 8/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6555 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 9/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6555 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 10/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6555 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 11/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6555 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 12/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6554 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 13/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 14/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 15/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6554 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 16/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6554 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 17/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 18/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 19/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6554 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 20/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6554 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 21/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 22/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 23/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 24/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 25/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 26/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 27/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6553 - val_loss: 0.6575 - learning_rate: 0.0100
# Epoch 28/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6575 - learning_rate: 0.0100
# Epoch 29/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 30/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 31/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 32/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 33/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 34/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 35/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6553 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 36/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 37/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 38/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 39/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 40/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 41/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 42/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 43/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6553 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 44/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 45/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 46/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 47/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 48/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 49/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 50/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 51/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 52/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 53/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 54/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 55/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 56/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 57/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 58/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 59/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 60/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 61/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 62/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 63/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 64/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 65/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6552 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 66/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 67/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 68/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 69/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 70/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 71/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 72/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 73/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 74/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6574 - learning_rate: 0.0050
# Epoch 75/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0050
# Epoch 76/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 77/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 78/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 79/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 80/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0025
# Epoch 81/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 82/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 83/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 84/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 85/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 86/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0025
# Epoch 87/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 88/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 89/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 90/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 91/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 92/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 93/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0025
# Epoch 94/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 95/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 96/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 97/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0025
# Epoch 98/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 99/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 100/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 101/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6573 - learning_rate: 0.0025
# Epoch 102/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0025
# Epoch 103/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 104/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 105/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 106/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0025
# Epoch 107/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0025
# Epoch 108/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 109/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 110/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 111/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 112/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 113/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 114/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 115/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 116/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 117/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 118/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 119/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 120/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 121/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 122/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 123/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 124/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 125/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 126/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 127/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 128/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 129/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 130/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6572 - learning_rate: 0.0012
# Epoch 131/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 132/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 133/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 134/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 135/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 136/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 137/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 138/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 139/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 0.0012
# Epoch 140/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 141/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 142/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 143/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 144/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 145/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 146/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 147/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 148/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 149/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 150/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 151/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 152/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 153/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 154/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 155/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 156/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 157/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 158/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 159/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 160/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 161/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 162/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 163/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 164/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 165/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 166/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 167/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 168/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 169/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 170/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 171/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6550 - val_loss: 0.6573 - learning_rate: 6.2500e-04
# Epoch 172/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 173/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 174/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 175/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 176/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 177/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 178/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 179/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 180/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 181/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 182/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 183/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 184/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 185/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 186/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 187/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 188/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 189/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 190/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 191/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 192/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 193/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 194/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 195/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 196/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 197/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 198/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 199/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Epoch 200/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - loss: 0.6549 - val_loss: 0.6573 - learning_rate: 3.1250e-04
# Fold 1 metrics: {'rmse': 14.1319, 'mae': 8.8964, 'r2': 0.9458, 'mard': 6.233}
#
# --- Fold 2/5 (glucose_level only (raw)) ---
# Epoch 1/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 0.6621 - val_loss: 0.6580 - learning_rate: 0.0100
# Epoch 2/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6560 - val_loss: 0.6578 - learning_rate: 0.0100
# Epoch 3/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6559 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 4/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6558 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 5/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6558 - val_loss: 0.6574 - learning_rate: 0.0100
# Epoch 6/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6557 - val_loss: 0.6573 - learning_rate: 0.0100
# Epoch 7/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6557 - val_loss: 0.6571 - learning_rate: 0.0100
# Epoch 8/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6557 - val_loss: 0.6570 - learning_rate: 0.0100
# Epoch 9/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6557 - val_loss: 0.6571 - learning_rate: 0.0100
# Epoch 10/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6556 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 11/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6556 - val_loss: 0.6570 - learning_rate: 0.0100
# Epoch 12/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6556 - val_loss: 0.6570 - learning_rate: 0.0100
# Epoch 13/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6556 - val_loss: 0.6571 - learning_rate: 0.0100
# Epoch 14/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6555 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 15/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6555 - val_loss: 0.6571 - learning_rate: 0.0100
# Epoch 16/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6555 - val_loss: 0.6571 - learning_rate: 0.0100
# Epoch 17/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6555 - val_loss: 0.6571 - learning_rate: 0.0100
# Epoch 18/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6555 - val_loss: 0.6570 - learning_rate: 0.0100
# Epoch 19/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6555 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 20/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6555 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 21/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6555 - val_loss: 0.6570 - learning_rate: 0.0100
# Epoch 22/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6555 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 23/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6555 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 24/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6555 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 25/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.6554 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 26/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6554 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 27/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 28/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 29/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6554 - val_loss: 0.6570 - learning_rate: 0.0100
# Epoch 30/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 31/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 32/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6554 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 33/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 34/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 35/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 36/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6554 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 37/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 38/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 39/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 40/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 41/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 42/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 43/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6554 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 44/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6554 - val_loss: 0.6570 - learning_rate: 0.0100
# Epoch 45/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 46/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 47/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 48/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6569 - learning_rate: 0.0100
# Epoch 49/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 50/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 51/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 52/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 53/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6554 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 54/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6553 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 55/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6553 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 56/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0100
# Epoch 57/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 58/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6553 - val_loss: 0.6568 - learning_rate: 0.0100
# Epoch 59/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0100
# Epoch 60/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 61/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 62/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 63/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 64/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 65/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 66/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 67/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 68/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 69/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 70/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 71/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 72/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 73/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 74/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 75/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 76/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 77/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 78/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 79/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 80/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 81/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 82/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 83/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 84/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6553 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 85/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 86/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 87/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 88/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 89/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 90/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 91/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 92/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0050
# Epoch 93/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 94/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 95/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 96/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 97/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 98/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 99/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 100/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 101/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 102/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 103/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 104/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 105/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 106/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 107/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 108/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 109/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 110/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 111/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 112/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 113/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 114/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 115/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 116/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 117/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 118/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 119/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 120/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 121/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 122/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 123/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6552 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 124/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0025
# Epoch 125/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 126/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 127/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 128/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 129/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 130/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 131/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 132/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 133/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 134/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 135/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 136/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 137/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 138/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 139/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 140/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 141/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 142/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 143/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 144/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 145/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 146/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 147/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 148/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 149/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 150/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 151/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 152/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 153/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 154/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 155/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 156/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 0.0012
# Epoch 157/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 158/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 159/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 160/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 161/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 162/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 163/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 164/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 165/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 166/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 167/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 168/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 169/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 170/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 171/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 172/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 173/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 174/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 175/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 176/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 177/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 178/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 179/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 180/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 181/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 182/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 183/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 184/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 185/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 186/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 187/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 188/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 6.2500e-04
# Epoch 189/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 3.1250e-04
# Epoch 190/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 3.1250e-04
# Epoch 191/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 3.1250e-04
# Epoch 192/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6551 - val_loss: 0.6567 - learning_rate: 3.1250e-04
# Fold 2 metrics: {'rmse': 14.1591, 'mae': 8.926, 'r2': 0.9447, 'mard': 6.2832}
#
# --- Fold 3/5 (glucose_level only (raw)) ---
# Epoch 1/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - loss: 0.6646 - val_loss: 0.6556 - learning_rate: 0.0100
# Epoch 2/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.6563 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 3/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6562 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 4/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6561 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 5/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6561 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 6/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6561 - val_loss: 0.6555 - learning_rate: 0.0100
# Epoch 7/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6561 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 8/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.6560 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 9/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6560 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 10/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.6560 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 11/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6560 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 12/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6560 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 13/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6560 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 14/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6559 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 15/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6559 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 16/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.6559 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 17/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.6559 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 18/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6559 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 19/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6559 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 20/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6559 - val_loss: 0.6552 - learning_rate: 0.0100
# Epoch 21/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6558 - val_loss: 0.6552 - learning_rate: 0.0100
# Epoch 22/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6558 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 23/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6558 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 24/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 0.6558 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 25/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.6558 - val_loss: 0.6553 - learning_rate: 0.0100
# Epoch 26/200
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6558 - val_loss: 0.6554 - learning_rate: 0.0100
# Epoch 27/200
# ...
# Epoch 73/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 74/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 75/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 76/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - loss: 0.6555 - val_loss: 0.6663 - learning_rate: 0.0050
# Epoch 77/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 78/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 79/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 80/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 81/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6663 - learning_rate: 0.0050
# Epoch 82/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 83/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 84/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0050
# Epoch 85/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6555 - val_loss: 0.6663 - learning_rate: 0.0050
# Epoch 86/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6663 - learning_rate: 0.0050
# Epoch 87/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 88/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 89/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 90/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 91/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 92/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 93/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 94/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 95/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 96/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 97/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 98/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 99/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 100/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 101/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 102/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 103/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 104/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 105/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 106/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 107/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 108/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 109/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 110/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 111/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 112/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 113/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 114/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 115/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6555 - val_loss: 0.6663 - learning_rate: 0.0025
# Epoch 116/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 117/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6555 - val_loss: 0.6662 - learning_rate: 0.0025
# Epoch 118/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.6555 - val_loss: 0.6663 - learning_rate: 0.0025
# Epoch 119/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 120/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 121/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 122/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 123/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 124/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 125/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 126/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 127/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 128/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 129/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 130/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 131/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 132/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 133/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 134/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 135/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 136/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 137/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 138/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 139/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 140/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 141/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 142/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 143/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 144/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 145/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 146/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 147/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 148/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 149/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 150/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 0.0012
# Epoch 151/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 152/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 153/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 154/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 155/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 156/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 157/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 158/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 159/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 160/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 161/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 162/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 163/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 164/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 165/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 166/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 167/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 168/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.6554 - val_loss: 0.6662 - learning_rate: 6.2500e-04
# Epoch 169/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 170/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 171/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 172/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 173/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 174/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 175/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 176/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 177/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 178/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 179/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 180/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 181/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 182/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 6.2500e-04
# Epoch 183/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 184/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 185/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 186/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 187/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 188/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 189/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 190/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 191/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 192/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 193/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 194/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 195/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 196/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 197/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 198/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 199/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
# Epoch 200/200
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.6554 - val_loss: 0.6663 - learning_rate: 3.1250e-04
#
# Result: {'model': 'STACKED_LSTM', 'features': 'glucose_level only (raw)', 'test_rmse': 13.0038, 'test_mae': 8.0959, 'test_r2': 0.9534, 'test_mard': 5.4919, 'cv_rmse_mean': np.float64(14.1421), 'cv_mae_mean': np.float64(8.8672), 'cv_r2_mean': np.float64(0.9452), 'cv_mard_mean': np.float64(6.2302), 'cv_rmse_std': 0.1586, 'cv_mae_std': 0.0811, 'cv_r2_std': 0.0012, 'cv_mard_std': 0.0499}
# Per-step test metrics (all 6 forecast horizons):
#   +5min: RMSE=4.2945  MAE=2.6722  MARD=1.8221%  R²=0.9949
#   +10min: RMSE=7.6569  MAE=4.9405  MARD=3.3578%  R²=0.9838
#   +15min: RMSE=10.7954  MAE=7.1149  MARD=4.8251%  R²=0.9679
#   +20min: RMSE=13.7168  MAE=9.2503  MARD=6.2709%  R²=0.9482
#   +25min: RMSE=16.4227  MAE=11.2982  MARD=7.6565%  R²=0.9258
#   +30min: RMSE=19.0557  MAE=13.2991  MARD=9.0192%  R²=0.9002
#           model                  features  test_rmse  test_mae  test_r2  \
# 0  STACKED_LSTM  glucose_level only (raw)    13.0038    8.0959   0.9534
#
#    test_mard  cv_rmse_mean  cv_mae_mean  cv_r2_mean  cv_mard_mean  \
# 0     5.4919       14.1421       8.8672      0.9452        6.2302
#
#    cv_rmse_std  cv_mae_std  cv_r2_std  cv_mard_std
# 0       0.1586      0.0811     0.0012       0.0499

# %%
# -----------------------------
# Quick visual check for the best run (all 6 forecast horizons)
# -----------------------------

import matplotlib.pyplot as plt

best         = results_df.iloc[0]
best_variant = next(v for v in variants if v["tag"] == best["features"])
best_preds   = predictions_by_tag[best["features"]]   # shape: N x fc_steps (mg/dL)
fc_steps     = CFG["forecast_minutes"] // CFG["freq_minutes"]
best_actual  = all_horizons(best_variant["y_test"])   # shape: N x fc_steps (mg/dL)

n = min(300, len(best_actual))

fig, axes = plt.subplots(fc_steps, 1, figsize=(14, 3 * fc_steps), sharex=True)
if fc_steps == 1:
    axes = [axes]

for step_idx, ax in enumerate(axes):
    step_min = (step_idx + 1) * CFG["freq_minutes"]
    ax.plot(best_actual[:n, step_idx], label="Actual", linewidth=1.0)
    ax.plot(best_preds[:n, step_idx],  label="Predicted", linewidth=1.0, linestyle="--")
    ax.set_title(f"t+{step_min} min  |  RMSE={best[f'test_rmse']:.4f}")
    ax.set_ylabel("Glucose (mg/dL)")
    ax.legend(loc="upper right")

axes[-1].set_xlabel("Test window index")
fig.suptitle(f"Best STACKED_LSTM: {best['features']} — all 6 forecast steps", fontsize=13)
plt.tight_layout()
plt.show()

print(f"Best variant: {best['features']}")
print(f"Test RMSE: {best['test_rmse']:.4f}  |  CV RMSE: {best['cv_rmse_mean']:.4f} ± {best['cv_rmse_std']:.4f}")
# Out:
# Best variant: glucose_level only (raw)
# Test RMSE: 13.0038  |  CV RMSE: 14.1421 ± 0.1586

# %%
# -----------------------------
# Print evaluation metrics — test phase + 5-fold CV (30-min prediction)
# -----------------------------

variant  = variants[0]   # glucose_level only (raw)
fc_steps = CFG["forecast_minutes"] // CFG["freq_minutes"]   # = 6

preds_s = model.predict(variant["X_test_3d"], verbose=0)            # N x fc_steps (scaled)
preds   = inverse_all_horizons(variant["scaler"], preds_s)           # N x fc_steps (mg/dL)
actual  = all_horizons(variant["y_test"])                            # N x fc_steps (mg/dL)

# ── Overall test metrics (flattened across all 6 steps) ───────────────────────
overall = compute_all_metrics(actual, preds)

print("=" * 50)
print(f"  Tag    : {variant['tag']}")
print(f"  Horizon: all 6 steps (t+5 min … t+30 min)")
print("  --- Test set (overall, all steps flattened) ---")
print(f"    MAE   : {overall['mae']:.4f} mg/dL")
print(f"    MARD  : {overall['mard']:.4f} %")
print(f"    R²    : {overall['r2']:.4f}")
print(f"    RMSE  : {overall['rmse']:.4f} mg/dL")
print()
print("  --- Test set, per-step breakdown ---")
for step_idx in range(fc_steps):
    step_min = (step_idx + 1) * CFG["freq_minutes"]
    m = compute_all_metrics(actual[:, step_idx:step_idx+1], preds[:, step_idx:step_idx+1])
    print(f"  t+{step_min:2d}min  RMSE={m['rmse']:.4f}  MAE={m['mae']:.4f}  MARD={m['mard']:.4f}%  R²={m['r2']:.4f}")
print("=" * 50)

# ── 5-fold cross-validation summary (training set) ────────────────────────────
cv_summary = cv_results_by_tag[variant["tag"]]["cv_overall_summary"]
print(f"\n  --- {CFG['cv']['n_splits']}-fold CV (training set, mean ± std) ---")
for m in ["rmse", "mae", "r2", "mard"]:
    print(f"    {m.upper():5s}: {cv_summary[f'cv_{m}_mean']:.4f} ± {cv_summary[f'cv_{m}_std']:.4f}")
print("=" * 50)
# Out:
# ==================================================
#   Tag    : glucose_level only (raw)
#   Horizon: all 6 steps (t+5 min … t+30 min)
#   --- Test set (overall, all steps flattened) ---
#     MAE   : 8.0959 mg/dL
#     MARD  : 5.4919 %
#     R²    : 0.9534
#     RMSE  : 13.0038 mg/dL
#
#   --- Test set, per-step breakdown ---
#   t+ 5min  RMSE=4.2945  MAE=2.6722  MARD=1.8221%  R²=0.9949
#   t+10min  RMSE=7.6569  MAE=4.9405  MARD=3.3578%  R²=0.9838
#   t+15min  RMSE=10.7954  MAE=7.1149  MARD=4.8251%  R²=0.9679
#   t+20min  RMSE=13.7168  MAE=9.2503  MARD=6.2709%  R²=0.9482
#   t+25min  RMSE=16.4227  MAE=11.2982  MARD=7.6565%  R²=0.9258
#   t+30min  RMSE=19.0557  MAE=13.2991  MARD=9.0192%  R²=0.9002
# ==================================================
#
#   --- 5-fold CV (training set, mean ± std) ---
#     RMSE : 14.1421 ± 0.1586
#     MAE  : 8.8672 ± 0.0811
#     R2   : 0.9452 ± 0.0012
#     MARD : 6.2302 ± 0.0499
# ==================================================

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

FREQ = CFG["freq_minutes"]
FORECAST_STEPS = CFG["forecast_minutes"] // FREQ  # 6

variant_tag = variants[0]["tag"]
preds       = predictions_by_tag[variant_tag]                 # N x fc_steps (mg/dL)
actual_all  = all_horizons(variants[0]["y_test"])              # N x fc_steps (mg/dL)

fig, axes = plt.subplots(FORECAST_STEPS, 1,
                          figsize=(14, 3.5 * FORECAST_STEPS),
                          sharex=True)

for step, ax in enumerate(axes, start=1):
    mins   = step * FREQ
    actual = actual_all[:, step - 1]
    pred   = preds[:, step - 1]
    n      = min(300, len(actual))

    rmse_val = float(np.sqrt(mean_squared_error(actual, pred)))
    mae_val  = float(mean_absolute_error(actual, pred))

    ax.plot(actual[:n], label="Actual",    color="#1d9e75", linewidth=1.1)
    ax.plot(pred[:n],   label="Predicted", color="#d85a30",
            linewidth=1.1, linestyle="--", alpha=0.85)
    ax.fill_between(range(n), actual[:n], pred[:n],
                    alpha=0.07, color="#d85a30")

    ax.set_title(f"t+{mins} min  —  RMSE {rmse_val:.2f}  MAE {mae_val:.2f} mg/dL",
                 fontsize=11, loc="left")
    ax.set_ylabel("mg/dL")
    ax.legend(loc="upper right", fontsize=9)
    ax.spines[["top", "right"]].set_visible(False)

axes[-1].set_xlabel("Test window index")
fig.suptitle(f"Stacked LSTM — all 6 forecast horizons\n"
             f"({variant_tag})", fontsize=13, y=1.01)
plt.tight_layout()
plt.show()

# %%
# -----------------------------
# Visualize 5-fold CV metrics per fold
# -----------------------------

import matplotlib.pyplot as plt

variant_tag  = variants[0]["tag"]
cv_overall_df = cv_results_by_tag[variant_tag]["cv_overall_df"]

fig, axes = plt.subplots(1, 4, figsize=(18, 4))
metrics_to_plot = ["rmse", "mae", "r2", "mard"]

for ax, metric in zip(axes, metrics_to_plot):
    values = cv_overall_df[metric].values
    folds  = np.arange(1, len(values) + 1)
    ax.bar(folds, values, color="#1d9e75", alpha=0.85)
    ax.axhline(values.mean(), color="#d85a30", linestyle="--", linewidth=1.2,
               label=f"mean={values.mean():.3f}")
    ax.set_title(metric.upper())
    ax.set_xlabel("Fold")
    ax.set_xticks(folds)
    ax.legend(fontsize=8)
    ax.spines[["top", "right"]].set_visible(False)

fig.suptitle(f"5-fold CV metrics per fold — {variant_tag}", fontsize=13)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

FREQ = CFG["freq_minutes"]
FORECAST_STEPS = CFG["forecast_minutes"] // FREQ  # 6

variant_tag = variants[0]["tag"]
preds       = predictions_by_tag[variant_tag]                 # N x fc_steps (mg/dL)
actual_all  = all_horizons(variants[0]["y_test"])              # N x fc_steps (mg/dL)

fig, axes = plt.subplots(2, 3, figsize=(15, 9))
axes = axes.ravel()

for step, ax in enumerate(axes, start=1):
    mins   = step * FREQ
    actual = actual_all[:, step - 1]
    pred   = preds[:, step - 1]
    r2     = r2_score(actual, pred)

    ax.scatter(actual, pred, s=3, alpha=0.25, color="#1d9e75")
    lim = [min(actual.min(), pred.min()) - 5,
           max(actual.max(), pred.max()) + 5]
    ax.plot(lim, lim, "k--", linewidth=0.8, label="Perfect fit")
    ax.set_xlim(lim); ax.set_ylim(lim)
    ax.set_title(f"t+{mins} min   R² = {r2:.3f}", fontsize=11)
    ax.set_xlabel("Actual (mg/dL)")
    ax.set_ylabel("Predicted (mg/dL)")
    ax.legend(fontsize=8)
    ax.spines[["top", "right"]].set_visible(False)

fig.suptitle("Actual vs predicted — all 6 horizons", fontsize=13)
plt.tight_layout()
plt.show()
